# %%
pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: selenium in c:\users\lotus\appdata\roaming\python\python313\site-packages (4.45.0)
# Requirement already satisfied: certifi>=2026.2.25 in c:\programdata\anaconda3\lib\site-packages (from selenium) (2026.5.20)
# Requirement already satisfied: trio<1.0,>=0.31.0 in c:\users\lotus\appdata\roaming\python\python313\site-packages (from selenium) (0.33.0)
# Requirement already satisfied: trio-websocket<1.0,>=0.12.2 in c:\users\lotus\appdata\roaming\python\python313\site-packages (from selenium) (0.12.2)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in c:\programdata\anaconda3\lib\site-packages (from selenium) (4.15.0)
# Requirement already satisfied: urllib3<3.0,>=2.6.3 in c:\users\lotus\appdata\roaming\python\python313\site-packages (from urllib3[socks]<3.0,>=2.6.3->selenium) (2.7.0)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in c:\programdata\anaconda3\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\programdata\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (25.4.0)
# Requirement already satisfied: sortedcontainers in c:\programdata\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (3.11)
# Requirement already satisfied: outcome in c:\users\lotus\appdata\roaming\python\python313\site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\programdata\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\programdata\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (2.0.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\lotus\appdata\roaming\python\python313\site-packages (from trio-websocket<1.0,>=0.12.2->selenium) (1.3.2)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\programdata\anaconda3\lib\site-packages (from urllib3[socks]<3.0,>=2.6.3->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.14->trio<1.0,>=0.31.0->selenium) (2.23)
# Requirement already satisfied: h11<1,>=0.16.0 in c:\programdata\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver # access browser and website
from selenium.webdriver.common.by import By # access web elements (tags,css, xpath)

# %%
website = "https://merolagani.com/LatestMarket.aspx"

# %%
driver = webdriver.Chrome() # used for edge browser so 
# driver = webdriver.chrome() # user for chrome

# %%
driver.get(website)

# %%
table_body = driver.find_element(By.TAG_NAME,'tbody')

# %%
table_rows = table_body.find_elements(By.TAG_NAME,'tr')
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 table_rows = table_body.find_elements(By.TAG_NAME,'tr')
#
# File ~\AppData\Roaming\Python\Python313\site-packages\selenium\webdriver\remote\webelement.py:556, in WebElement.find_elements(self, by, value)
#     535 """Find elements given a By strategy and locator.
#     536
#     537 Args:
#    (...)    553     element = driver.find_elements(By.ID, "foo")
#     554 """
#     555 by, value = self._parent.locator_converter.convert(by, value)
# --> 556 return self._execute(Command.FIND_CHILD_ELEMENTS, {"using": by, "value": value})["value"]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\selenium\webdriver\remote\webelement.py:508, in WebElement._execute(self, command, params)
#     506     params = {}
#     507 params["id"] = self._id
# --> 508 return self._parent.execute(command, params)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\selenium\webdriver\remote\webdriver.py:492, in WebDriver.execute(self, driver_command, params)
#     489 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     491 if response:
# --> 492     self.error_handler.check_response(response)
#     493     response["value"] = self._unwrap_value(response.get("value", None))
#     494     return response
#
# File ~\AppData\Roaming\Python\Python313\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)
# --> 232 raise exception_class(message, screen, stacktrace)
#
# StaleElementReferenceException: Message: stale element reference: stale element not found in the current frame
#   (Session info: chrome=149.0.7827.116); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#staleelementreferenceexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0x7ff711663fa5+14925]
# 	chromedriver!GetHandleVerifier [0x7ff711664000+14980]
# 	chromedriver!(No symbol) [0x7ff7111a793d]
# 	chromedriver!(No symbol) [0x7ff7111af8b1]
# 	chromedriver!(No symbol) [0x7ff7111b2875]
# 	chromedriver!(No symbol) [0x7ff7111b293f]
# 	chromedriver!(No symbol) [0x7ff71120122a]
# 	chromedriver!(No symbol) [0x7ff711201dac]
# 	chromedriver!(No symbol) [0x7ff7111f5e2c]
# 	chromedriver!(No symbol) [0x7ff7111f57c6]
# 	chromedriver!(No symbol) [0x7ff71124f39b]
# 	chromedriver!(No symbol) [0x7ff7111f401c]
# 	chromedriver!(No symbol) [0x7ff7111f4f43]
# 	chromedriver!GetHandleVerifier [0x7ff711c47591+5f7f11]
# 	chromedriver!GetHandleVerifier [0x7ff711c41902+5f2282]
# 	chromedriver!GetHandleVerifier [0x7ff711c67115+617a95]
# 	chromedriver!GetHandleVerifier [0x7ff711681dce+3274e]
# 	chromedriver!GetHandleVerifier [0x7ff71168a82c+3b1ac]
# 	chromedriver!GetHandleVerifier [0x7ff71166d744+1e0c4]
# 	chromedriver!GetHandleVerifier [0x7ff71166d8d4+1e254]
# 	chromedriver!GetHandleVerifier [0x7ff711651447+1dc7]
# 	KERNEL32!BaseThreadInitThunk [0x7ffc7da6e957+17]
# 	ntdll!RtlUserThreadStart [0x7ffc7f547c1c+2c]

# %%
# for data in table_rows:
#     columns = data.find_elements(By.TAG_NAME,'td')
# for col in columns:
#     print(col.text)

# %%
symbol_col= []
ltp_col = []
change_col =[]
open_col=[]
high_col = []
low_col = []
qty_col = []
pclose_col = []
diff_col = []

# %%
for row in table_rows:
    columns = row.find_elements(By.TAG_NAME, 'td')

    if len(columns) < 9:
        continue
    symbol_col.append(columns[0].text)
    ltp_col.append(columns[1].text)
    change_col.append(columns[2].text)
    open_col.append(columns[3].text)
    high_col.append(columns[4].text)
    low_col.append(columns[5].text)
    qty_col.append(columns[6].text)
    pclose_col.append(columns[7].text)
    diff_col.append(columns[8].text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 for row in table_rows:
#       2     columns = row.find_elements(By.TAG_NAME, 'td')
#       4     if len(columns) < 9:
#
# NameError: name 'table_rows' is not defined

# %%
symbol_col
# Out:
# []

# %%
data_frame = {
    'Symbol': symbol_col,
    'LTP': ltp_col,
    'Change': change_col,
    'Open': open_col,
    'High': high_col,
    'Low': low_col,
    'Quantity': qty_col,
    'P_Close': pclose_col,
    'Difference': diff_col
}

# %%
driver.quit()

# %%
import pandas as pd

# %%
df = pd.DataFrame(data_frame)

# %%
df.to_csv('stocks.csv', index=False)
# data.to_json('stocks.csv', index=False)

# %%
df
# Out:
# Empty DataFrame
# Columns: [Symbol, LTP, Change, Open, High, Low, Quantity, P_Close, Difference]
# Index: []

# %%
# df.to_json('stocks.csv', index=False) # if u want to store it in json file
